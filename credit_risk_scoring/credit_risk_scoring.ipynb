# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('../data/CreditScoring.csv')

df.head()
# Out:
#    Status  Seniority  Home  Time  Age  Marital  Records  Job  Expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    Income  Assets  Debt  Amount  Price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.columns  = df.columns.str.lower()

df.head()
# Out:
#    status  seniority  home  time  age  marital  records  job  expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.status.value_counts()
# Out:
# status
# 1    3200
# 2    1254
# 0       1
# Name: count, dtype: int64

# %%
status_values = {
    1: "ok",
    2: "default",
    0: "unknown"
}
df.status = df.status.map(status_values)
df.head()
# Out:
#     status  seniority  home  time  age  marital  records  job  expenses  \
# 0       ok          9     1    60   30        2        1    3        73
# 1       ok         17     1    60   58        3        1    1        48
# 2  default         10     2    36   46        2        2    3        90
# 3       ok          0     1    60   24        1        1    1        63
# 4       ok          0     1    36   26        1        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
home_values = {
    1: 'rent',
    2: 'owner',
    3: 'private',
    4: 'ignore',
    5: 'parents',
    6: 'other',
    0: 'unk'
}

df.home = df.home.map(home_values)

marital_values = {
    1: 'single',
    2: 'married',
    3: 'widow',
    4: 'separated',
    5: 'divorced',
    0: 'unk'
}

df.marital = df.marital.map(marital_values)

records_values = {
    1: 'no',
    2: 'yes',
    0: 'unk'
}

df.records = df.records.map(records_values)

job_values = {
    1: 'fixed',
    2: 'partime',
    3: 'freelance',
    4: 'others',
    0: 'unk'
}

df.job = df.job.map(job_values)

df.head()
# Out:
#     status  seniority   home  time  age  marital records        job  expenses  \
# 0       ok          9   rent    60   30  married      no  freelance        73
# 1       ok         17   rent    60   58    widow      no      fixed        48
# 2  default         10  owner    36   46  married     yes  freelance        90
# 3       ok          0   rent    60   24   single      no      fixed        63
# 4       ok          0   rent    36   26   single      no      fixed        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.describe()
# Out:
#          seniority         time          age     expenses        income  \
# count  4455.000000  4455.000000  4455.000000  4455.000000  4.455000e+03
# mean      7.987205    46.441751    37.077666    55.568799  7.633170e+05
# std       8.173444    14.655225    10.984856    19.515878  8.703625e+06
# min       0.000000     6.000000    18.000000    35.000000  0.000000e+00
# 25%       2.000000    36.000000    28.000000    35.000000  8.000000e+01
# 50%       5.000000    48.000000    36.000000    51.000000  1.200000e+02
# 75%      12.000000    60.000000    45.000000    72.000000  1.660000e+02
# max      48.000000    72.000000    68.000000   180.000000  1.000000e+08
#
#              assets          debt       amount         price
# count  4.455000e+03  4.455000e+03  4455.000000   4455.000000
# mean   1.060341e+06  4.043820e+05  1039.021773   1462.875645
# std    1.021757e+07  6.344253e+06   474.543007    628.089913
# min    0.000000e+00  0.000000e+00   100.000000    105.000000
# ...

# %%
for c in ['income', 'assets', 'debt']:
   df[c] = df[c].replace(to_replace=99999999, value=np.nan)

df.describe().round()
# Out:
#        seniority    time     age  expenses  income    assets     debt  amount  \
# count     4455.0  4455.0  4455.0    4455.0  4421.0    4408.0   4437.0  4455.0
# mean         8.0    46.0    37.0      56.0   131.0    5403.0    343.0  1039.0
# std          8.0    15.0    11.0      20.0    86.0   11573.0   1246.0   475.0
# min          0.0     6.0    18.0      35.0     0.0       0.0      0.0   100.0
# 25%          2.0    36.0    28.0      35.0    80.0       0.0      0.0   700.0
# 50%          5.0    48.0    36.0      51.0   120.0    3000.0      0.0  1000.0
# 75%         12.0    60.0    45.0      72.0   165.0    6000.0      0.0  1300.0
# max         48.0    72.0    68.0     180.0   959.0  300000.0  30000.0  5000.0
#
#          price
# count   4455.0
# mean    1463.0
# std      628.0
# min      105.0
# 25%     1118.0
# 50%     1400.0
# 75%     1692.0
# max    11140.0

# %%
df = df[df.status != 'unkown'].reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split

df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=11)
df_train, df_validation = train_test_split(df_full_train, test_size=0.25, random_state=11)

df_test = df_test.reset_index(drop=True)
df_validation = df_validation.reset_index(drop=True)
df_train = df_train.reset_index(drop=True)

# %%
y_train = (df_train.status == 'default').astype('int').values
y_val = (df_validation.status == 'default').astype('int').values
y_test = (df_test.status == 'default').astype('int').values

# %%
del df_train['status']
del df_validation['status']
del df_test['status']

# %%
df_train
# Out:
#       seniority     home  time  age    marital records        job  expenses  \
# 0             3     rent    36   61    married      no      fixed        41
# 1             5     rent    48   30  separated     yes    partime        39
# 2            15    owner    60   32   divorced      no  freelance        35
# 3             2     rent    12   47    married     yes      fixed       103
# 4             6  parents    48   32     single     yes      fixed        35
# ...         ...      ...   ...  ...        ...     ...        ...       ...
# 2668          1  parents    60   21     single      no    partime        35
# 2669          5     rent    60   47     single     yes      fixed        46
# 2670         23     rent    24   47     single      no      fixed        44
# 2671          5    owner    60   58    married      no  freelance        45
# 2672          4    owner    48   22    married      no      fixed        35
#
#       income   assets    debt  amount  price
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer

train_dicts = df_train.fillna(0).to_dict(orient='records')

dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(train_dicts)

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
"""
    What we see from the
    ROC AUC score between the validation datasets and training datasets,
    tells us that the decision tree is overfitting aka without a depth limit
    and a min_samples_split limit and a min_samples_leaf limit it creates
    a hyperspecific branch for examples and too many leaf nodes encompassing outliers, and when a new unseen data comes in it struggles in placing it
    along the right trajectory which leads to a ROC AUC of 0.66
"""


from sklearn.metrics import roc_auc_score

validation_dicts = df_validation.fillna(0).to_dict(orient='records')
X_val = dv.transform(validation_dicts)

y_pred = dt.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred)
print('Validation: ', auc)

y_pred = dt.predict_proba(X_train)[:, 1]
auc = roc_auc_score(y_train, y_pred)
print('Train: ', auc)
# Out:
# Validation:  0.6688277976241981
# Train:  1.0

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(X_train,y_train)

y_pred = dt.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred)
print('Validation: ', auc)

y_pred = dt.predict_proba(X_train)[:, 1]
auc = roc_auc_score(y_train, y_pred)
print('Train: ', auc)
# Out:
# Validation:  0.763427236430611
# Train:  0.7660925386129352

# %%
"""
    Here if we set the max_depth to equal 1 then we get underfitting
    which for decision trees is called DECISION STUMP
"""


dt = DecisionTreeClassifier(max_depth=1)
dt.fit(X_train,y_train)

y_pred = dt.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred)
print('Validation: ', auc)

y_pred = dt.predict_proba(X_train)[:, 1]
auc = roc_auc_score(y_train, y_pred)
print('Train: ', auc)
# Out:
# Validation:  0.6131750701491985
# Train:  0.6271176710091984

# %%
for depth in [1, 2, 3, 4, 5, 6, 10, 15, 20, 40, 80, 100, 150, 200, None]:
    dt = DecisionTreeClassifier(max_depth=depth)
    dt.fit(X_train, y_train)
    y_pred = dt.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_pred)
    print('%4s -> %.3f' % (depth, auc))
# Out:
#    1 -> 0.613
#    2 -> 0.688
#    3 -> 0.763
#    4 -> 0.779
#    5 -> 0.784
#    6 -> 0.773
#   10 -> 0.704
#   15 -> 0.669
#   20 -> 0.673
#   40 -> 0.668
#   80 -> 0.674
#  100 -> 0.673
#  150 -> 0.666
#  200 -> 0.674
# None -> 0.662

# %% [markdown]
# <h2 align='center'>Ensembles and random forest</h2>

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=10)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
y_pred = rf.predict_proba(X_val)[:, 1]

roc_auc_score(y_val, y_pred)
# Out:
# 0.811011260955018

# %%
scores = []

for n in range(10, 201, 10):
    rf = RandomForestClassifier(n_estimators=n, random_state=1)
    rf.fit(X_train, y_train)
    
    y_pred = rf.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_pred)
    scores.append((n, auc))

df_scores = pd.DataFrame(scores, columns=['n_estimators', 'auc'])
df_scores
# Out:
#     n_estimators       auc
# 0             10  0.809417
# 1             20  0.835251
# 2             30  0.832906
# 3             40  0.830872
# 4             50  0.832235
# 5             60  0.831864
# 6             70  0.833122
# 7             80  0.834735
# 8             90  0.833292
# 9            100  0.833907
# 10           110  0.834649
# 11           120  0.835131
# 12           130  0.836219
# 13           140  0.837826
# 14           150  0.837730
# 15           160  0.837504
# 16           170  0.836741
# 17           180  0.836997
# 18           190  0.837646
# 19           200  0.836973

# %%
plt.plot(df_scores.n_estimators, df_scores.auc)

# %%
scores = []

for d in [5, 10, 15]:
    for n in range(10, 201, 10):
        rf = RandomForestClassifier(n_estimators=n, max_depth=d, random_state=1)
        rf.fit(X_train, y_train)
        
        y_pred = rf.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)
        scores.append((d, n, auc))

df_scores = pd.DataFrame(scores, columns=['max_depth', 'n_estimators', 'auc'])
df_scores
# Out:
#     max_depth  n_estimators       auc
# 0           5            10  0.816836
# 1           5            20  0.822065
# 2           5            30  0.822084
# 3           5            40  0.824846
# 4           5            50  0.828793
# 5           5            60  0.831463
# 6           5            70  0.831642
# 7           5            80  0.830968
# 8           5            90  0.831240
# 9           5           100  0.831067
# 10          5           110  0.830919
# 11          5           120  0.829998
# 12          5           130  0.830010
# 13          5           140  0.829596
# 14          5           150  0.828972
# 15          5           160  0.829677
# 16          5           170  0.830319
# 17          5           180  0.830332
# 18          5           190  0.830944
# 19          5           200  0.830567
# 20         10            10  0.805730
# 21         10            20  0.823805
# 22         10            30  0.825177
# 23         10            40  0.834627
# ...

# %%
for d in [5, 10, 15]:
    df_subset = df_scores[df_scores.max_depth == d]
    
    plt.plot(df_subset.n_estimators, df_subset.auc, label='max_depth=%d' % d)
    
plt.legend()

# %%
import xgboost as xgb

# %%
features = dv.feature_names_
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)

dval = xgb.DMatrix(X_val, label=y_val, feature_names=features)

xgb_params = {
    'eta': 0.3,
    'max_depth': 6,
    'min_child_weight': 1,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread': 8,
    
    'seed': 1,
    'verbosity': 1,
}

watchlist = [(dtrain, 'train'), (dval, 'val')]

model = xgb.train(xgb_params, dtrain, num_boost_round=100, evals=watchlist)

y_pred = model.predict(dval)

roc_auc_score(y_val, y_pred)
# Out:
# [0]	train-auc:0.85841	val-auc:0.79382
# [1]	train-auc:0.88469	val-auc:0.80343
# [2]	train-auc:0.89778	val-auc:0.81381
# [3]	train-auc:0.90579	val-auc:0.81585
# [4]	train-auc:0.91422	val-auc:0.82115
# [5]	train-auc:0.92470	val-auc:0.82481
# [6]	train-auc:0.93339	val-auc:0.82782
# [7]	train-auc:0.93857	val-auc:0.82841
# [8]	train-auc:0.94291	val-auc:0.82819
# [9]	train-auc:0.94557	val-auc:0.82767
# [10]	train-auc:0.94874	val-auc:0.82736
# [11]	train-auc:0.95247	val-auc:0.82989
# [12]	train-auc:0.95490	val-auc:0.83247
# [13]	train-auc:0.95817	val-auc:0.83310
# [14]	train-auc:0.96010	val-auc:0.83340
# [15]	train-auc:0.96329	val-auc:0.83282
# [16]	train-auc:0.96465	val-auc:0.83390
# [17]	train-auc:0.96600	val-auc:0.83435
# [18]	train-auc:0.96770	val-auc:0.83299
# [19]	train-auc:0.96973	val-auc:0.83472
# [20]	train-auc:0.97048	val-auc:0.83393
# [21]	train-auc:0.97304	val-auc:0.83380
# [22]	train-auc:0.97438	val-auc:0.83197
# [23]	train-auc:0.97556	val-auc:0.83059
# ...
